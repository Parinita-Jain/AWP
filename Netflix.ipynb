# %% [markdown]
# <a href="https://colab.research.google.com/github/Parinita-Jain/AWP/blob/main/Netflix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the provided Netflix data CSV file
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data
file_path = "Netflix.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#           Languages Series or Movie  Hidden Gem Score  \
# 0  Swedish, Spanish          Series               4.3
# 1           English           Movie               7.0
# 2           English           Movie               6.4
# 3           Turkish          Series               7.7
# 4           English           Movie               8.1
#
#                                 Country Availability       Runtime  \
# 0                                           Thailand  < 30 minutes
# 1                                             Canada      1-2 hour
# 2                                             Canada      1-2 hour
# 3                                Belgium,Netherlands  < 30 minutes
# 4  Lithuania,Poland,France,Iceland,Italy,Spain,Gr...      1-2 hour
#
#           Director                      Writer  \
# 0  Tomas Alfredson       John Ajvide Lindqvist
# 1    Coky Giedroyc               Caitlin Moran
# 2    Brendan Walsh  Brendan Walsh, Daley Nixon
# 3              NaN                         NaN
# 4    Stephen Irwin                         NaN
#
#                                               Actors View Rating  IMDb Score  \
# 0  Kåre Hedebrant, Per Ragnar, Lina Leandersson, ...           R         7.9
# 1  Paddy Considine, Cleo, Beanie Feldstein, Dónal...           R         5.8
# 2                  Genesis Rodriguez, Vincent Piazza     Unrated         4.3
# 3  Vahide Perçin, Gonca Vuslateri, Cansu Dere, Be...         NaN         6.5
# 4                                       Ragga Gudrun         NaN         6.3
#
#    Rotten Tomatoes Score  Metacritic Score  Awards Nominated For   Boxoffice  \
# 0                   98.0              82.0                  57.0  $2,122,065
# 1                   79.0              69.0                   NaN     $70,632
# 2                    NaN              46.0                   NaN     $16,263
# 3                    NaN               NaN                   NaN         NaN
# 4                    NaN               NaN                   4.0         NaN
#
#   Release Date Netflix Release Date                            Netflix Link  \
# 0    12-Dec-08           04-03-2021  https://www.netflix.com/watch/81415947
# 1    08-May-20           04-03-2021  https://www.netflix.com/watch/81041267
# 2    28-Aug-20           04-03-2021  https://www.netflix.com/watch/81305978
# 3    01-Oct-16           04-03-2021  https://www.netflix.com/watch/81336456
# 4    22-Sep-11           04-03-2021  https://www.netflix.com/watch/81078393
#
#    IMDb Votes
# 0    205926.0
# 1      2838.0
# 2      1720.0
# 3      1147.0
# 4        63.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15483 entries, 0 to 15482
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9227 non-null   object
#  1   Genre                  7886 non-null   object
#  2   Languages              7678 non-null   object
#  3   Series or Movie        9227 non-null   object
#  4   Hidden Gem Score       7605 non-null   float64
#  5   Country Availability   9216 non-null   object
#  6   Runtime                9227 non-null   object
#  7   Director               6076 non-null   object
#  8   Writer                 6127 non-null   object
#  9   Actors                 7735 non-null   object
#  10  View Rating            3999 non-null   object
#  11  IMDb Score             7746 non-null   float64
#  12  Rotten Tomatoes Score  2771 non-null   float64
#  13  Metacritic Score       1658 non-null   float64
#  14  Awards Nominated For   3770 non-null   float64
#  15  Boxoffice              1434 non-null   object
#  16  Release Date           7796 non-null   object
#  17  Netflix Release Date   9368 non-null   object
#  18  Netflix Link           9368 non-null   object
#  19  IMDb Votes             7745 non-null   float64
# dtypes: float64(6), object(14)
# memory usage: 2.4+ MB

# %%
df["Boxoffice"] = df["Boxoffice"].str.replace("[$,]+", "", regex=True).astype(float)
df.head()

'''
Explanation of changes:

Adding regex=True: The primary issue is with the way the str.replace method is being used.
By default, it operates with literal strings, not regular expressions.
To correctly interpret the [,$]+ pattern as a regular expression targeting
one or more occurrences of '$' or ',', we need to include the regex=True argument.
This allows the replacement to target and remove these special characters within the 'Boxoffice' column's values.
'''
# Out:
# "\nExplanation of changes:\n\nAdding regex=True: The primary issue is with the way the str.replace method is being used. By default, it operates with literal strings, not regular expressions. To correctly interpret the [,$]+ pattern as a regular expression targeting one or more occurrences of '$' or ',', we need to include the regex=True argument. This allows the replacement to target and remove these special characters within the 'Boxoffice' column's values.\n"

# %%
#A Box-office hit film means a film which has grossed $20,00,000. Find the number of Box-Office Hit Films.
box_office_hits=df[(df['Series or Movie']=='Movie')&(df['Boxoffice']>=2000000)]
num_box_office_hits=len(box_office_hits)
print(f"Number of Box-Office Hit Films: {num_box_office_hits}")
# Out:
# Number of Box-Office Hit Films: 669

# %%
#A critically acclaimed movie means a film that has IMDB rating of atleast 8. Find the number of such films.
critically_acclaimed = df[(df['Series or Movie'] == 'Movie') & (df['IMDb Score'] >= 8)]
num_critically_acclaimed=len(critically_acclaimed)
print(f"Number of Critically Acclaimed Movies: {num_critically_acclaimed}")
# Out:
# Number of Critically Acclaimed Movies: 219

# %%
# Find aLL criticaLLy acclaimed movies which are	Box-off!ce  Hits
critically_acclaimed_hits = df[(df['Series or Movie'] == 'Movie') &
(df['IMDb Score'] >= 8) & (df['Boxoffice']>=2000000)]
print(critically_acclaimed_hits)
# Out:
#                                            Title  \
# 15                                         Joker
# 17                              Harrys Daughters
# 69                                   Stand by Me
# 421                             The Elephant Man
# 697                        Me & You vs The World
# 865                                     Fiction.
# 1139                               Girls Revenge
# 1218                                        1917
# 1595                                    Parasite
# 1722                                       Joker
# 1748                                    Sin City
# 2790                                       2 дня
# 2841                        Честное пионерское 2
# 2844                        Честное пионерское 3
# 3633                        Howl’s Moving Castle
# 3805                                   Apollo 11
# 4008                     The Biggest Little Farm
# 4425                         Gods Little Village
# 4603   Three Billboards Outside Ebbing, Missouri
# 4765                     They Shall Not Grow Old
# 4869                                  Green Book
# 5341           Spider-Man: Into the Spider-Verse
# 6187                                    Magnolia
# 6235                          Dances with Wolves
# 6237                               Casino Royale
# 6239                    Wont You Be My Neighbor?
# 6635                 Blade Runner: The Final Cut
# 6859                                       Alien
# 6931  Baahubali: The Beginning (English Version)
# 7098                           Blade Runner 2049
# 7190                                      Wonder
# 8259                                      Aliens
# 8647                 Monty Pythons Life of Brian
#
#                                               Genre  \
# 15                           Crime, Drama, Thriller
# 17               Adventure, Drama, Fantasy, Mystery
# 69                                 Adventure, Drama
# 421                                Biography, Drama
# 697                         Biography, Crime, Drama
# 4451                   The Irishman         7.9                 334.0
# 327                   Sesame Street         8.1                 317.0
# 5556                 Will and Grace         7.2                 313.0
# ...                             ...         ...                   ...
# 4042                         Curtiz         6.0                   5.0
# 4043                           1945         7.1                   5.0
# 4084                          Cheer         8.1                   5.0
# 7014     Violet Evergarden: Special         8.4                   5.0
# 5525        Wanda Sykes: Not Normal         7.2                   5.0
#
# [1711 rows x 3 columns]

# %%
#Find all critically acclaimed tv series for United States.
critically_acclaimed_tv_us = df[(df['Series or Movie'] == 'TV Series')
            & (df['IMDb Score'] >= 8)
            & (df["Country Availability"]=="United States")]
print("Critically Acclaimed TV Series from the United States")
print(critically_acclaimed_tv_us[['Title',	"IMDb Score", "Country Availability" ] ])
# Out:
# Critically Acclaimed TV Series from the United States
# Empty DataFrame
# Columns: [Title, IMDb Score, Country Availability]
# Index: []

# %%
#IMDB Rating is based on IMDB Votes. Find all films which inspite of receiving at least. 100 votes did not receive any award.
df["Awards Nominated For"]=df["Awards Nominated For"].fillna(0)
films_with_votes_no_awards = df[(df['Series or Movie'] == 'Movie') &
         (df['IMDb Votes'] >= 100) & (df["Awards Nominated For"]==0)]
print("Films with at least 100 votes but no awards:")
print(films_with_votes_no_awards[['Title', 'IMDb Votes', 'Awards Nominated For'] ])
# Out:
# Films with at least 100 votes but no awards:
#                                      Title  IMDb Votes  Awards Nominated For
# 1                      HOW TO BUILD A GIRL      2838.0                   0.0
# 2                               Centigrade      1720.0                   0.0
# 5                         The Con-Heartist       131.0                   0.0
# 9                               Snowroller      5926.0                   0.0
# 19                          False As Water       546.0                   0.0
# ...                                    ...         ...                   ...
# 9208                   48 Christmas Wishes       931.0                   0.0
# 9209  Jeremiah Tower: The Last Magnificent       441.0                   0.0
# 9210           Russell Howard: Recalibrate      1308.0                   0.0
# 9214                        Sune i fjällen       766.0                   0.0
# 9218                             The Climb       165.0                   0.0
#
# [2181 rows x 3 columns]

# %%
#A popular film means it is released at Netflix platforms within 1 year.
#Find all Films which were released in Netflix within 2 years of actual release.
#--
# convert release year to date and extract year
df['Release_Year']=pd.to_datetime(df['Release Date'],errors='coerce').dt.year
# convert netflix release datetime to datetime and extract year
df['Netflix Release Year']=pd.to_datetime(df['Netflix Release Date'],errors='coerce').dt.year

YearOffset=(df['Netflix Release Year']-df['Release_Year']).abs()
# filtering logic for movies released within 2 years of actual release
films_released=df[(df['Series or Movie'] == 'Movie') &
         (YearOffset<=2)]
print("Films Released On Netflix Within 2 Years of actual Release")
print(films_released[['Title', 'Release_Year', 'Netflix Release Year']])
# Out:
# <ipython-input-61-2a08a44d1210>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Release_Year']=pd.to_datetime(df['Release Date'],errors='coerce').dt.year
# Films Released On Netflix Within 2 Years of actual Release
#                          Title  Release_Year  Netflix Release Year
# 1          HOW TO BUILD A GIRL        2020.0                2021.0
# 2                   Centigrade        2020.0                2021.0
# 5             The Con-Heartist        2020.0                2021.0
# 15                       Joker        2019.0                2021.0
# 24             Indoo Ki Jawani        2020.0                2021.0
# ...                        ...           ...                   ...
# 9067            Mustang Island        2018.0                2018.0
# 9069          Almost Christmas        2016.0                2018.0
# 9070           An Ordinary Man        2018.0                2018.0
# 9071               Planetarium        2017.0                2018.0
# 9073  Boruto: Naruto the Movie        2017.0                2018.0
#
# [1570 rows x 3 columns]

# %%
#Popular Films available in Canada
popular_films_canada=df[df["Country Availability"]=="Canada"]
print("popular Films Available in Canada :")
print(popular_films_canada[['Title', 'Release_Year', 'Netflix Release Year']])
# Out:
# popular Films Available in Canada :
#                                Title  Release_Year  Netflix Release Year
# 1                HOW TO BUILD A GIRL        2020.0                2021.0
# 2                         Centigrade        2020.0                2021.0
# 25                       The Coroner        2015.0                2021.0
# 124                       Collective        2020.0                   NaN
# 143                         Unhinged        2020.0                   NaN
# ...                              ...           ...                   ...
# 8293                    Game Shakers        2015.0                2018.0
# 8326                   Certain Women        2017.0                2018.0
# 8455  Billy Lynns Long Halftime Walk        2016.0                2018.0
# 8495               Beatriz at Dinner        2017.0                   NaN
# 8952                      24: Legacy        2017.0                2018.0
#
# [83 rows x 3 columns]

# %%
# Movies with a runtime of 1 hr
# Convert "Runtime" to numeric by extracting number of minutes
df["Runtime"]=df["Runtime"].str.extract(r'(\d+)').astype(float)
# filter movies with a runtime of atleast 1 hour (60 minutes)
movies_runtime = df[(df["Series or Movie"]=="Movie")&
                    (df["Runtime"]>=1)]
# Display filtered movies--
print("Movies with a runtime of 1 hour or more:")
print(movies_runtime[["Title","Runtime"]])
# Out:
# Movies with a runtime of 1 hour or more:
#                         Title  Runtime
# 1         HOW TO BUILD A GIRL      1.0
# 2                  Centigrade      1.0
# 4                       Moxie      1.0
# 5            The Con-Heartist      2.0
# 8               Only a Mother      1.0
# ...                       ...      ...
# 9221            The Foreigner      1.0
# 9222  劇場版 フェアリーテイル DRAGON CRY      1.0
# 9224               Live Flesh      1.0
# 9225  The Flower of My Secret      1.0
# 9226            Bad Education      1.0
#
# [6883 rows x 2 columns]

# %%
# Series created in more than 1 language
multilingual_tv_series=df[(df["Series or Movie"]=="Series")
                       &(df['Languages'].str.contains(','))]
print("Series created in more than 1 language:")
multilingual_tv_series[["Title","Languages"]]
# Out:
# Series created in more than 1 language:
#                             Title  \
# 0                Lets Fight Ghost
# 46                   The New Pope
# 54                          Alice
# 95              Operation Buffalo
# 147                      The Crew
# ...                           ...
# 9176             Panda! Go Panda!
# 9217   Ultimate Beastmaster India
# 9219   Ultimate Beastmaster China
# 9220  Ultimate Beastmaster France
# 9223   Ultimate Beastmaster Spain
#
#                                               Languages
# 0                                      Swedish, Spanish
# 46                                     English, Italian
# 54                                   English, Cantonese
# 95                                  English, Aboriginal
# 147                                    English, Spanish
# ...                                                 ...
# 9176                                  Japanese, English
# 9217  English, Spanish, Korean, Japanese, German, Po...
# 9219  English, Spanish, Korean, Japanese, German, Po...
# 9220  English, Spanish, Korean, Japanese, German, Po...
# 9223  English, Spanish, Korean, Japanese, German, Po...
#
# [249 rows x 2 columns]

# %%
# Movies available in Japan and fall in more than 1 genre
movies_in_japan=df[(df["Series or Movie"]=="Movie")
                   &(df["Country Availability"]=="Japan")
                   &(df['Genre'].str.contains(','))]
print("Movies available in Japan and fall in more than 1 genre:")
movies_in_japan[["Title","Genre"]]
# Out:
# Movies available in Japan and fall in more than 1 genre:
#                                Title                                Genre
# 29                    The Mysterians     Action, Family, Sci-Fi, Thriller
# 30                   No Longer Human           Biography, Drama, Thriller
# 32                              Sway                         Crime, Drama
# 35                            Gorath     Action, Family, Sci-Fi, Thriller
# 37                   Floating Clouds                       Drama, Romance
# ...                              ...                                  ...
# 9157  Kamen Rider 555: Paradise Lost       Action, Drama, Fantasy, Sci-Fi
# 9161                Independents Day  Action, Adventure, Sci-Fi, Thriller
# 9170                            Rage             Drama, Mystery, Thriller
# 9171                   Drowning Love                       Drama, Romance
# 9174             The Masked Rider #1           Action, Adventure, Fantasy
#
# [304 rows x 2 columns]

# %%
# Films with large summary
films_with_large_summary=df[(df["Series or Movie"]=="Movie")&
  (df["Title"].str.len()>50)]
print("Films with large summary:")
print(films_with_large_summary["Title"])
# Out:
# Films with large summary:
# 433     Elcano & Magellan: The First Voyage around the...
# 437     Doraemon: Nobitas Chronicle of the Moon Explor...
# 499     Kishiryu Sentai Ryusoulger The Movie: Time Sli...
# 521     Gintama: The Movie: The Final Chapter: Be Fore...
# 840     Godzilla, Mothra and King Ghidorah: Giant Mons...
#                               ...
# 8750    John Bishop: Supersonic Live at the Royal Albe...
# 9027    Mobile Suit Z Gundam: A New Translation - Heir...
# 9028    Mobile Suit Z Gundam: A New Translation II - L...
# 9033    Mobile Suit Z Gundam III: Love Is the Pulse of...
# 9159    A Certain Magical Index: The Movie －The Miracl...
# Name: Title, Length: 113, dtype: object

# %%
# Films with a total rating of atleast 15
films_high_rating = df[(df["Series or Movie"]=="Movie")&
  ((df["IMDb Score"]+df["Hidden Gem Score"])>=15)]
print("Films with a total rating of atleast 15:")
print(films_high_rating[["Title","Hidden Gem Score","IMDb Score"]])
# Out:
# Films with a total rating of atleast 15:
#                                Title  Hidden Gem Score  IMDb Score
# 5                   The Con-Heartist               8.6         7.4
# 8                      Only a Mother               8.3         6.7
# 12        The Simple Minded Murderer               7.8         7.6
# 14                   To Kill a Child               8.8         7.7
# 18                     Gyllene Tider               8.8         7.7
# ...                              ...               ...         ...
# 9150              Galaxy Express 999               8.2         7.4
# 9157  Kamen Rider 555: Paradise Lost               8.5         7.1
# 9169  Ushijima the Loan Shark Part 3               8.4         6.8
# 9186                         McLaren               7.7         7.3
# 9210     Russell Howard: Recalibrate               8.4         7.4
#
# [980 rows x 3 columns]

# %%
# Dramatic Series from Japan
dramatic_series_japan=df[(df["Series or Movie"]=="Series")&
  (df["Genre"].str.contains("Drama"))&
  (df["Country Availability"]=="Japan")]
print("Dramatic Series from Japan:")
dramatic_series_japan[["Title","Country Availability","Genre"]]
# Out:
# Dramatic Series from Japan:
#                                 Title Country Availability  \
# 107                Princess Principal                Japan
# 115                       Oh My JUMP!                Japan
# 229                       Stolen face                Japan
# 254                      Ace Attorney                Japan
# 364                       Idoly Pride                Japan
# ...                               ...                  ...
# 9088  Rurouni Kenshin: Shin Kyoto-Hen                Japan
# 9164              Seitokai Yakuindomo                Japan
# 9166            The Laughing Salesman                Japan
# 9168                         OISHINBO                Japan
# 9175                    Fruits Basket                Japan
#
#                                             Genre
# 107   Animation, Action, Adventure, Drama, Sci-Fi
# 115                                         Drama
# 229                                  Crime, Drama
# 254       Comedy, Crime, Drama, Mystery, Thriller
# 364                       Animation, Drama, Music
# ...                                           ...
# 9088                     Animation, Action, Drama
# 9164                     Animation, Comedy, Drama
# 9166             Animation, Comedy, Drama, Horror
# 9168                                        Drama
# 9175   Animation, Comedy, Drama, Fantasy, Romance
#
# [67 rows x 3 columns]

# %%
# films directed by persons whose name starts with "C".
films_directed_by_c=df[(df["Series or Movie"]=="Movie")&
  (df["Director"].str.startswith("C"))]
print("films directed by persons whose name starts with 'C':")
films_directed_by_c[["Title","Director"]]
# Out:
# films directed by persons whose name starts with 'C':
#                                Title  \
# 1                HOW TO BUILD A GIRL
# 56                        Magic hour
# 82                       Criticsized
# 83              Communication & Lies
# 153                   Story of Women
# ...                              ...
# 9188                        Verónica
# 9190                       The Climb
# 9211  The Nut Job 2: Nutty by Nature
# 9216                   Staying Alive
# 9218                       The Climb
#
#                                        Director
# 1                                 Coky Giedroyc
# 56                                 Cole Mueller
# 82                                Carl T. Evans
# 83                            Christopher Banks
# 153                              Claude Chabrol
# ...                                         ...
# 9188  Carlos Algara, Alejandro Martinez-Beltran
# 9190                             Chris Robinson
# 9211                                Cal Brunker
# 9216                             Charlotte Blom
# 9218                             Chris Robinson
#
# [277 rows x 2 columns]

# %%
# films directed by Christopher Nolan and ending with 'O'
films_directed_by_christopher_nolan=df[(df["Series or Movie"]=="Movie")&
  (df["Director"]=="Christopher Nolan")&
  (df["Title"].str.endswith("o"))]

print("films directed by Christopher Nolan and ending with 'o':")
films_directed_by_christopher_nolan[["Title","Director"]]
# Out:
# films directed by Christopher Nolan and ending with 'o':
# Empty DataFrame
# Columns: [Title, Director]
# Index: []

# %%
# films directed and written by Christopher Nolan
films_directed_and_written_by_christopher_nolan=df[(df["Series or Movie"]=="Movie")&
  (df["Director"]=="Christopher Nolan")&
  (df["Writer"]=="Christopher Nolan")]

print("films directed and written by Christopher Nolan:")
films_directed_and_written_by_christopher_nolan[["Title","Director","Writer"]]
# Out:
# films directed and written by Christopher Nolan:
#         Title           Director             Writer
# 8441  Dunkirk  Christopher Nolan  Christopher Nolan

# %%
# English movie names with IMDb Score more than 8.5
english_movies_high_imdb=df[(df["Series or Movie"]=="Movie")&
  (df["Languages"]=="English")&
  (df["IMDb Score"]>8.5)]

print("English movie names with IMDb Score more than 8.5:")
english_movies_high_imdb[["Title","Languages","IMDb Score"]]
# Out:
# English movie names with IMDb Score more than 8.5:
#                                          Title Languages  IMDb Score
# 42                                    5 Minute   English         8.6
# 218                              As Seen On Tv   English         8.6
# 1337  David Attenborough: A Life on Our Planet   English         9.0
# 1904                             Downton Abbey   English         8.7
# 2113                              Line of Duty   English         8.7
# 6437                    Bill Hicks: Relentless   English         8.7
# 7177                                Conspiracy   English         9.2
# 8012                           The Consuls Son   English         9.1
